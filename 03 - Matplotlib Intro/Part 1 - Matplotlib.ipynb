# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,100)
y = np.sqrt(x)
y1 = np.sin(x)
y2 = np.cos(x)

# %% [markdown]
# ## Inisialisasi Figure dan Axes

# %%
fig = plt.figure()
ax = plt.axes()

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.axes()
ax.plot(x,y)

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.axes()
ax.plot(x,y1)
ax.plot(x,y2)

# %% [markdown]
# ## shortcut

# %%
plt.figure(figsize=(6,6))
plt.plot(x,y1, 'r:')
plt.plot(x,y2, 'bo', linewidth=8)

plt.xlim(0,10)
plt.ylim(-2,2)
plt.axis('equal')
plt.title('sin dan cos')
plt.xlabel("sumbu x")
plt.ylabel("sumbu y");

# %% [markdown]
# ## Scatter Plot

# %%
df = pd.read_csv('data/circle_data.csv', delimiter=";")
df.head()
# Out:
#           x         y    radius
# 0  0.064608  0.548028  0.551823
# 1 -0.277651  0.424200  0.506987
# 2 -0.477146 -0.157482  0.502463
# 3  0.031218 -0.169573  0.172423
# 4 -0.048724  0.736632  0.738242

# %%
x = df.x
y = df.y
rad = df.radius

# %%
plt.scatter(x,y)
plt.axis('equal');

# %%
plt.scatter(x,y, c='r', s=10)
plt.axis('equal');

# %%
plt.scatter(x,y, c=rad, s=rad*50, cmap="seismic")
plt.axis('equal');

# %% [markdown]
# ## Histogram

# %%
numbers = np.random.rand(10000)
plt.hist(numbers, bins=25);

# %%
numbers = np.random.randn(10000)
plt.hist(numbers, bins=80);

# %%
numbers = np.random.randn(10000)
plt.hist(numbers, bins=80, density=1);

# %%
numbers = np.random.randn(10000)
plt.hist(numbers, bins=80, density=1, cumulative=True);

# %% [markdown]
# ## Subplot

# %% [markdown]
# ### Matlab Style

# %%
plt.figure(figsize=(15,10))

plt.subplot(231) # kalau ada dua digit pisahkan pakai koma aja contoh (3,5,10)
plt.hist(numbers, bins=80, density=1);

plt.subplot(233)
plt.hist(numbers, bins=80, density=1);

plt.subplot(235)
plt.scatter(x,y, c='r', s=10)
plt.axis('equal');

plt.subplot(236)
plt.hist(numbers, bins=80, density=1, cumulative=True);

# %% [markdown]
# ### Matplotlib Style

# %%
fig, ax =plt.subplots(2,3, figsize=(15,10))

ax[0,0].hist(numbers, bins=80, density=1);

ax[0,1].axis('off')

ax[0,2].hist(numbers, bins=80, density=1);

ax[1,0].axis('off')

ax[1,1].scatter(x,y, c='r', s=10)
ax[1,1].axis('equal');


ax[1,2].hist(numbers, bins=80, density=1, cumulative=True);

# %%
fig, ax =plt.subplots(2,3, figsize=(15,10), sharey=True, sharex=True)

ax[0,0].hist(numbers, bins=80, density=1);

ax[0,2].hist(numbers, bins=80, density=1);

ax[1,1].scatter(x,y, c='r', s=10)

ax[1,2].hist(numbers, bins=80, density=1, cumulative=True);

# %% [markdown]
# ## Text dan Anotation

# %%
numbers = np.random.randn(10000)

# %%
plt.figure(figsize=(6,6))
plt.hist(numbers, bins=80, density=1);
plt.ylim(0,1)
plt.axvline(0, color='r');
plt.text(0,0.8,"mean=0", ha='center')
plt.annotate("mean=0", xy=(0,0.4), xytext=(1,0.5), ha="center", arrowprops={'arrowstyle':'-|>'})
# Out:
# Text(1, 0.5, 'mean=0')

# %% [markdown]
# ## 3D Plot

# %%
from mpl_toolkits import mplot3d

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')

# %%
x = np.linspace(-6,6,100)
y = np.linspace(-6,6,100)

X, Y = np.meshgrid(x,y)
Z = np.sqrt(X**2 + Y**2 + 10)

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.plot_surface(X,Y,Z, antialiased=False, cmap='winter');

ax.set(xlabel="sumbu x", ylabel="sumbu y", zlabel="sumbu z")
# Out:
# [Text(0.5, 0, 'sumbu z'), Text(0.5, 0, 'sumbu y'), Text(0.5, 0, 'sumbu x')]

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.plot_surface(X,Y,Z, antialiased=False, cmap='winter');

ax.set(xlabel="sumbu x", ylabel="sumbu y", zlabel="sumbu z")

# elev itu atas bawah dan azimut itu kiri kanan, satuannya drajat
ax.view_init(elev=-30, azim=45)

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.plot_wireframe(X,Y,Z, cmap='winter');

ax.set(xlabel="sumbu x", ylabel="sumbu y", zlabel="sumbu z")

# elev itu atas bawah dan azimut itu kiri kanan, satuannya drajat
ax.view_init(elev=-30, azim=45)

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection='3d')
ax.contour3D(X,Y,Z, 50, cmap='winter');

ax.set(xlabel="sumbu x", ylabel="sumbu y", zlabel="sumbu z")

# elev itu atas bawah dan azimut itu kiri kanan, satuannya drajat
ax.view_init(elev=-30, azim=45)
